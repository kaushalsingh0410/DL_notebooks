# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
# Gradient Descent:-

# %%
# SGD:- Stochastic Gradient Descent:
# MB SGD:- Mini Batch Stochastic Gradient Descent

# %% [markdown]
# ![bp_update_formula.png](attachment:bp_update_formula.png)

# %% [markdown]
# ![1_gBKKTy4KrwH6R-K0yUzVAw.png](attachment:1_gBKKTy4KrwH6R-K0yUzVAw.png)

# %%
# initial loss:
# initial w:- 
# learning rate:- 0.001

# %%
# 40K---2L---4L
# 1 epoch:- 4L:-W
# 10 epoch:- 4L:- arrays(W)

# %%
# y = mx + c
# z = w*x + b

# %%
#  SGD:- Stochastic Gradient Descent:

# %%
# 40K---2l:- 4L

# %%
#  Mini batch SGD:- mini batch Stochastic Gradient Descent:

# %%
# batch size = 1000

# %%
# 1L

# %%
100000/1000
# Out:
# 100.0

# %%
# Adagrad:- Adaptive gradient descent

# %% [markdown]
# # learning rate:- fixed
# # adaptive learning rate

# %% [markdown]
# ![gradient_descent_variations_nn.webp](attachment:gradient_descent_variations_nn.webp)

# %% [markdown]
# ![1_nNYrbDVc0qhZHUDdp-KI0A.png](attachment:1_nNYrbDVc0qhZHUDdp-KI0A.png)

# %% [markdown]
# ![1_n79s9gvd0E8ALe9dLUEKAw.png](attachment:1_n79s9gvd0E8ALe9dLUEKAw.png)

# %% [markdown]
# ![Credit-Analytics-Vidya.jpg](attachment:Credit-Analytics-Vidya.jpg)

# %% [markdown]
# ![0_lETgf8vtqTvtMrcR.png](attachment:0_lETgf8vtqTvtMrcR.png)
