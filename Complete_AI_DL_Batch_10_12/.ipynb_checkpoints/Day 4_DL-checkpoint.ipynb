# %%
import tensorflow as tf
print('done')
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# done

# %%
print(dir(tf))
# Out:
# ['AggregationMethod', 'Assert', 'CriticalSection', 'DType', 'DeviceSpec', 'GradientTape', 'Graph', 'IndexedSlices', 'IndexedSlicesSpec', 'Module', 'Operation', 'OptionalSpec', 'RaggedTensor', 'RaggedTensorSpec', 'RegisterGradient', 'SparseTensor', 'SparseTensorSpec', 'Tensor', 'TensorArray', 'TensorArraySpec', 'TensorShape', 'TensorSpec', 'TypeSpec', 'UnconnectedGradients', 'Variable', 'VariableAggregation', 'VariableSynchronization', '_API_MODULE', '_KerasLazyLoader', '_LazyLoader', '__all__', '__builtins__', '__cached__', '__compiler_version__', '__cxx11_abi_flag__', '__cxx_version__', '__doc__', '__file__', '__git_version__', '__internal__', '__loader__', '__monolithic_build__', '__name__', '__operators__', '__package__', '__path__', '__spec__', '__version__', '_api', '_compat', '_current_file_location', '_current_module', '_distutils', '_estimator_module', '_fi', '_initializers', '_inspect', '_kernel_dir', '_ll', '_logging', '_losses', '_major_api_version', '_metrics', '_module_d
# ...

# %%
# 0d:- sacler data:- zero dimension:- tensor
# 1d:- vector:- 1d dimensional:- tensor
# 2d:- matrix:- 2d dimension:- tensor
# 3d:- tensors
    
# cpu
# gpu
# tpu

# %%
# tensor:- array:- tensor

# %%
# neutron:- point of zero dimension: infinite gravity

# %%
import numpy as np

# %%
a = np.array(10)
print(a)
# Out:
# 10

# %%
a.shape
# Out:
# ()

# %%
a.ndim
# Out:
# 0

# %%
# tf.constant:- immutable
# tf.Variable:- mutable

# %%
a = tf.constant(10)
print(a)
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
a.shape
# Out:
# TensorShape([])

# %%
a.ndim
# Out:
# 0

# %%
a = np.array([1,12,434,56])

print(a)
# Out:
# [  1  12 434  56]

# %%
b = tf.constant(a)
print(b)
# Out:
# tf.Tensor([  1  12 434  56], shape=(4,), dtype=int32)

# %%
a.shape
# Out:
# (4,)

# %%
b.shape
# Out:
# TensorShape([4])

# %%
a.dtype
# Out:
# dtype('int32')

# %%
b.dtype
# Out:
# tf.int32

# %%
# 2d

a = np.array([[11,23,234],[1,243,5],[2,34,45]])
print(a)
# Out:
# [[ 11  23 234]
#  [  1 243   5]
#  [  2  34  45]]

# %%
b = tf.constant(a)
print(b)
# Out:
# tf.Tensor(
# [[ 11  23 234]
#  [  1 243   5]
#  [  2  34  45]], shape=(3, 3), dtype=int32)

# %%
# 3d

a = np.random.randint(1,100,(3,3,3))
print(a)
# Out:
# [[[25 92 89]
#   [ 7 99 58]
#   [28 99 55]]
#
#  [[67 14 40]
#   [46 43  9]
#   [14 62 65]]
#
#  [[45 71 62]
#   [64 95 19]
#   [96 18 95]]]

# %%
b = tf.constant(a)
print(b)
# Out:
# tf.Tensor(
# [[[25 92 89]
#   [ 7 99 58]
#   [28 99 55]]
#
#  [[67 14 40]
#   [46 43  9]
#   [14 62 65]]
#
#  [[45 71 62]
#   [64 95 19]
#   [96 18 95]]], shape=(3, 3, 3), dtype=int32)

# %%
# 4d

a = np.random.randint(1,100,(3,3,3,3))
print(a)
# Out:
# [[[[46 98 19]
#    [22  4 16]
#    [97 55 56]]
#
#   [[28 47 26]
#    [89 89 22]
#    [39 33 33]]
#
#   [[12 10 67]
#    [81 39 50]
#    [74 27  4]]]
#
#
#  [[[50 77 51]
#    [45 18 50]
#    [88  3 97]]
#
#   [[30 33  8]
#    [12 68 38]
#    [88 71 73]]
#
#   [[65 37 56]
#    [30 22 54]
#    [54 95 23]]]
#
#
#  [[[ 6 85 91]
#    [91 90 50]
#    [74 55  9]]
#
#   [[93 94  9]
#    [64 29 13]
#    [79 65 39]]
#
#   [[14 87 40]
#    [82  6 24]
#    [57 28 99]]]]

# %%
b = tf.constant(a)
print(b)
# Out:
# tf.Tensor(
# [[[[46 98 19]
#    [22  4 16]
#    [97 55 56]]
#
#   [[28 47 26]
#    [89 89 22]
#    [39 33 33]]
#
#   [[12 10 67]
#    [81 39 50]
#    [74 27  4]]]
#
#
#  [[[50 77 51]
#    [45 18 50]
#    [88  3 97]]
#
#   [[30 33  8]
#    [12 68 38]
#    [88 71 73]]
#
#   [[65 37 56]
#    [30 22 54]
#    [54 95 23]]]
#
#
#  [[[ 6 85 91]
#    [91 90 50]
#    [74 55  9]]
#
#   [[93 94  9]
#    [64 29 13]
#    [79 65 39]]
#
#   [[14 87 40]
#    [82  6 24]
#    [57 28 99]]]], shape=(3, 3, 3, 3), dtype=int32)

# %%
# Variable

# %%
a = np.array([[1,24,53],[12,435,34]])
print(a)
# Out:
# [[  1  24  53]
#  [ 12 435  34]]

# %%
b_m = tf.Variable([1,234,546,35])

print(b)
# Out:
# tf.Tensor([  1 234 546  35], shape=(4,), dtype=int32)

# %%
b_im = tf.constant([1,234,546,35])

print(b)
# Out:
# tf.Tensor([  1 234 546  35], shape=(4,), dtype=int32)

# %%
print(b_im[2])
# Out:
# tf.Tensor(546, shape=(), dtype=int32)

# %%
b_im[2] = 34
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 b_im[2] = 34
#
# TypeError: 'tensorflow.python.framework.ops.EagerTensor' object does not support item assignment

# %%
f = (1,243,56)

f[2] = 34
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 f = (1,243,56)
# ----> 3 f[2] = 34
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(b_m)
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([  1, 234, 546,  35])>

# %%
print(b_m[2])
# Out:
# tf.Tensor(546, shape=(), dtype=int32)

# %%
b_m[2] = 345678
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 b_m[2] = 345678
#
# TypeError: 'ResourceVariable' object does not support item assignment

# %%
print(dir(b_m[2]))
# Out:
# ['OVERLOADABLE_OPERATORS', '_USE_EQUALITY', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__bool__', '__class__', '__complex__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__iter__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__tf_tensor__', '__tf_tracing_type__', '__truediv__', '__weakref__', '__xor__', '_add_consum
# ...

# %%
b_m[2].assign(12345)
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([    1,   234, 12345,    35])>

# %%
print(b_m)
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([    1,   234, 12345,    35])>

# %%
print(dir(b_im[2]))
# Out:
# ['OVERLOADABLE_OPERATORS', '_USE_EQUALITY', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__bool__', '__class__', '__complex__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__iter__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__tf_tensor__', '__tf_tracing_type__', '__truediv__', '__weakref__', '__xor__', '_add_consum
# ...

# %%
'assign' in dir(b_im[2])
# Out:
# False

# %%
'assign' in dir(b_m[2])
# Out:
# True

# %%
b_im[2].assign(345678)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 b_im[2].assign(345678)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:261, in Tensor.__getattr__(self, name)
#     253 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     254             "tolist", "data"}:
#     255   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     256   raise AttributeError(
#     257       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     258     If you are looking for numpy-related methods, please run the following:
#     259     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     260   """)
# --> 261 self.__getattribute__(name)
#
# AttributeError: 'tensorflow.python.framework.ops.EagerTensor' object has no attribute 'assign'

# %%
'ggcfhg'.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 'ggcfhg'.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
tensor_a = tf.constant([1,24,345,6])
tensor_b = tf.constant([1,24,345,6])

# %%
print(tensor_a)
# Out:
# tf.Tensor([  1  24 345   6], shape=(4,), dtype=int32)

# %%
print(tensor_a+10)
# Out:
# tf.Tensor([ 11  34 355  16], shape=(4,), dtype=int32)

# %%
print(tensor_a-10)
print(tensor_a*10)
print(tensor_a/10)
print(tensor_a//10)
print(tensor_a**10)
print(tensor_a%2)
# Out:
# tf.Tensor([ -9  14 335  -4], shape=(4,), dtype=int32)
# tf.Tensor([  10  240 3450   60], shape=(4,), dtype=int32)
# tf.Tensor([ 0.1  2.4 34.5  0.6], shape=(4,), dtype=float64)
# tf.Tensor([ 0  2 34  0], shape=(4,), dtype=int32)
# tf.Tensor([          1  1073741824 -1134543183    60466176], shape=(4,), dtype=int32)
# tf.Tensor([1 0 1 0], shape=(4,), dtype=int32)

# %%
# imp func
# type casting
# broadcasting
# masking

# %%
# imp func

# %%
print(tensor_a)
# Out:
# tf.Tensor([  1  24 345   6], shape=(4,), dtype=int32)

# %%
tensor_a = tf.constant([1,24.9,345,6])

print(tensor_a)
# Out:
# tf.Tensor([  1.   24.9 345.    6. ], shape=(4,), dtype=float32)

# %%
# reduce_

print(tf.reduce_max(tensor_a))
print(tf.reduce_mean(tensor_a))
print(tf.reduce_min(tensor_a))
print(tf.reduce_prod(tensor_a))
print(tf.reduce_sum(tensor_a))
# Out:
# tf.Tensor(345.0, shape=(), dtype=float32)
# tf.Tensor(94.225, shape=(), dtype=float32)
# tf.Tensor(1.0, shape=(), dtype=float32)
# tf.Tensor(51543.0, shape=(), dtype=float32)
# tf.Tensor(376.9, shape=(), dtype=float32)

# %%
np.array(tensor_a).mean()
# Out:
# 94.0

# %%
sum([ 1 ,24 ,345 , 6])/4
# Out:
# 94.0

# %%
print(sum(tensor_a))
# Out:
# tf.Tensor(376.9, shape=(), dtype=float32)

# %%
print(tensor_a)
# Out:
# tf.Tensor([  1.   24.9 345.    6. ], shape=(4,), dtype=float32)

# %%
tensor_a = tf.Variable(np.random.randint(1,50,(3,3)))
print(tensor_a)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[47,  4, 26],
#        [30, 20, 20],
#        [22, 38, 30]])>

# %%
# reduce_ with axis

print(tf.reduce_max(tensor_a))
# Out:
# tf.Tensor(47, shape=(), dtype=int32)

# %%
print(tf.reduce_max(tensor_a,axis = 1))  # 1 row
# Out:
# tf.Tensor([47 30 38], shape=(3,), dtype=int32)

# %%
print(tf.reduce_max(tensor_a,axis = 0))  # 0 col
# Out:
# tf.Tensor([47 38 30], shape=(3,), dtype=int32)

# %%
print(tf.reduce_mean(tensor_a,axis = 1))
print(tf.reduce_min(tensor_a,axis = 1))
print(tf.reduce_prod(tensor_a,axis = 1))
print(tf.reduce_sum(tensor_a,axis = 1))
# Out:
# tf.Tensor([25 23 30], shape=(3,), dtype=int32)
# tf.Tensor([ 4 20 22], shape=(3,), dtype=int32)
# tf.Tensor([ 4888 12000 25080], shape=(3,), dtype=int32)
# tf.Tensor([77 70 90], shape=(3,), dtype=int32)

# %%
print(tf.reduce_mean(tensor_a,axis = 0))
print(tf.reduce_min(tensor_a,axis = 0))
print(tf.reduce_prod(tensor_a,axis = 0))
print(tf.reduce_sum(tensor_a,axis = 0))
# Out:
# tf.Tensor([33 20 25], shape=(3,), dtype=int32)
# tf.Tensor([22  4 20], shape=(3,), dtype=int32)
# tf.Tensor([31020  3040 15600], shape=(3,), dtype=int32)
# tf.Tensor([99 62 76], shape=(3,), dtype=int32)

# %%
# type casting

# %%
print(tensor_a)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[47,  4, 26],
#        [30, 20, 20],
#        [22, 38, 30]])>

# %%
a
# Out:
# array([[  1,  24,  53],
#        [ 12, 435,  34]])

# %%
tensor_a = tf.Variable(a)
print(tensor_a)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[  1,  24,  53],
#        [ 12, 435,  34]])>

# %%
tensor_a = tf.Variable(a,dtype = tf.int16)
print(tensor_a)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int16, numpy=
# array([[  1,  24,  53],
#        [ 12, 435,  34]], dtype=int16)>

# %%
tensor_a = tf.Variable(a,dtype = tf.float64)
print(tensor_a)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float64, numpy=
# array([[  1.,  24.,  53.],
#        [ 12., 435.,  34.]])>

# %%
# type casting

# %%
print(tensor_a )
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float64, numpy=
# array([[  1.,  24.,  53.],
#        [ 12., 435.,  34.]])>

# %%
tf.cast(tensor_a,tf.bool)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=bool, numpy=
# array([[ True,  True,  True],
#        [ True,  True,  True]])>

# %%
a = tf.constant(-100)
print(a)
# Out:
# tf.Tensor(-100, shape=(), dtype=int32)

# %%
print(tf.cast(a,list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 print(tf.cast(a,list))
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\dtypes.py:852, in as_dtype(type_value)
#     849 if isinstance(type_value, _dtypes.DType):
#     850   return _INTERN_TABLE[type_value.as_datatype_enum]
# --> 852 raise TypeError(f"Cannot convert the argument `type_value`: {type_value!r} "
#     853                 "to a TensorFlow DType.")
#
# ...

# %%
list(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 list(a)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:326, in Tensor.__iter__(self)
#     323 if not context.executing_eagerly():
#     324   self._disallow_iteration()
# --> 326 first_dim = self._get_first_dim()
#     327 return _TensorIterator(self, first_dim)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:334, in Tensor._get_first_dim(self)
#     332   raise TypeError("Cannot iterate over a tensor with unknown shape.")
#     333 if not shape:
# --> 334   raise TypeError("Cannot iterate over a scalar tensor.")
#     335 if shape[0] is None:
#     336   raise TypeError(
#     337       "Cannot iterate over a tensor with unknown first dimension.")
#
# TypeError: Cannot iterate over a scalar tensor.

# %%
list(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 list(10)
#
# TypeError: 'int' object is not iterable

# %%
print(tf.cast(a,tf.bool))
# Out:
# tf.Tensor(True, shape=(), dtype=bool)

# %%
a = tf.constant([0])
print(a)
# Out:
# tf.Tensor([0], shape=(1,), dtype=int32)

# %%
print(tf.cast(a,tf.bool))
# Out:
# tf.Tensor([False], shape=(1,), dtype=bool)

# %%
print(tf.cast(a,str))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 print(tf.cast(a,str))
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\dtypes.py:852, in as_dtype(type_value)
#     849 if isinstance(type_value, _dtypes.DType):
#     850   return _INTERN_TABLE[type_value.as_datatype_enum]
# --> 852 raise TypeError(f"Cannot convert the argument `type_value`: {type_value!r} "
#     853                 "to a TensorFlow DType.")
#
# ...

# %%
a = tf.Variable([False,True,False,False,True,True])
print(a)
# Out:
# <tf.Variable 'Variable:0' shape=(6,) dtype=bool, numpy=array([False,  True, False, False,  True,  True])>

# %%
tf.cast(a,tf.int32)
# Out:
# <tf.Tensor: shape=(6,), dtype=int32, numpy=array([0, 1, 0, 0, 1, 1])>

# %%
# masking 

a = np.random.randint(1,100,(5,5))
print(a)
# Out:
# [[33 92 77 70 23]
#  [62 73 30 20 97]
#  [17 35 51 42 39]
#  [63  8 63 84 65]
#  [66  3 28 56 55]]

# %%
tensor_a = tf.constant(a)
print(tensor_a)
# Out:
# tf.Tensor(
# [[33 92 77 70 23]
#  [62 73 30 20 97]
#  [17 35 51 42 39]
#  [63  8 63 84 65]
#  [66  3 28 56 55]], shape=(5, 5), dtype=int32)

# %%
# VLSI:- V

# %%
# tsmc:

# %%
# masking

# %%
print(tensor_a >= 30)
# Out:
# tf.Tensor(
# [[ True  True  True  True False]
#  [ True  True  True False  True]
#  [False  True  True  True  True]
#  [ True False  True  True  True]
#  [ True False False  True  True]], shape=(5, 5), dtype=bool)

# %%
print(tensor_a[tensor_a >= 30])
# Out:
# tf.Tensor([33 92 77 70 62 73 30 97 35 51 42 39 63 63 84 65 66 56 55], shape=(19,), dtype=int32)

# %%
tensor_a[tensor_a % 2 == 0]
# Out:
# <tf.Tensor: shape=(11,), dtype=int32, numpy=array([92, 70, 62, 30, 20, 42,  8, 84, 66, 28, 56])>

# %%
tensor_a[tensor_a % 2 != 0]
# Out:
# <tf.Tensor: shape=(14,), dtype=int32, numpy=array([33, 77, 23, 73, 97, 17, 35, 51, 39, 63, 63, 65,  3, 55])>

# %%
tensor_a[~(tensor_a % 2 == 0)]
# Out:
# <tf.Tensor: shape=(14,), dtype=int32, numpy=array([33, 77, 23, 73, 97, 17, 35, 51, 39, 63, 63, 65,  3, 55])>

# %%
tensor_a[(tensor_a % 2 == 0)  & (tensor_a % 3 == 0)]
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([30, 42, 84, 66])>

# %%
tensor_a[(tensor_a % 2 == 0)  | (tensor_a % 3 == 0)]
# Out:
# <tf.Tensor: shape=(17,), dtype=int32, numpy=array([33, 92, 70, 62, 30, 20, 51, 42, 39, 63,  8, 63, 84, 66,  3, 28, 56])>

# %%
tensor_a[~(tensor_a % 2 == 0)  | (tensor_a % 3 == 0)]
# Out:
# <tf.Tensor: shape=(18,), dtype=int32, numpy=
# array([33, 77, 23, 73, 30, 97, 17, 35, 51, 42, 39, 63, 63, 84, 65, 66,  3,
#        55])>

# %%
tensor_a
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[33, 92, 77, 70, 23],
#        [62, 73, 30, 20, 97],
#        [17, 35, 51, 42, 39],
#        [63,  8, 63, 84, 65],
#        [66,  3, 28, 56, 55]])>

# %%
tf.where(tensor_a>30)
# Out:
# <tf.Tensor: shape=(18, 2), dtype=int64, numpy=
# array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [1, 4],
#        [2, 1],
#        [2, 2],
#        [2, 3],
#        [2, 4],
#        [3, 0],
#        [3, 2],
#        [3, 3],
#        [3, 4],
#        [4, 0],
#        [4, 3],
#        [4, 4]], dtype=int64)>

# %%
print(tensor_a[1][4])
# Out:
# tf.Tensor(97, shape=(), dtype=int32)

# %%
tf.where(tensor_a>30,1000,0)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[1000, 1000, 1000, 1000,    0],
#        [1000, 1000,    0,    0, 1000],
#        [   0, 1000, 1000, 1000, 1000],
#        [1000,    0, 1000, 1000, 1000],
#        [1000,    0,    0, 1000, 1000]])>

# %%
tf.where(tensor_a>30,1000,tensor_a)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[1000, 1000, 1000, 1000,   23],
#        [1000, 1000,   30,   20, 1000],
#        [  17, 1000, 1000, 1000, 1000],
#        [1000,    8, 1000, 1000, 1000],
#        [1000,    3,   28, 1000, 1000]])>

# %%
tensor_a
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[33, 92, 77, 70, 23],
#        [62, 73, 30, 20, 97],
#        [17, 35, 51, 42, 39],
#        [63,  8, 63, 84, 65],
#        [66,  3, 28, 56, 55]])>

# %%
# >80 Out
# out <25

# %%
tf.clip_by_value(tensor_a,25,80)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[33, 80, 77, 70, 25],
#        [62, 73, 30, 25, 80],
#        [25, 35, 51, 42, 39],
#        [63, 25, 63, 80, 65],
#        [66, 25, 28, 56, 55]])>

# %%
# row column, indexing, slicing

# %%
# ANN: FNN
# CNN
# RNN

# %%
tensor_a
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[33, 92, 77, 70, 23],
#        [62, 73, 30, 20, 97],
#        [17, 35, 51, 42, 39],
#        [63,  8, 63, 84, 65],
#        [66,  3, 28, 56, 55]])>

# %%
# tensor_a[r,c]

# %%
tensor_a[2:4,:]
# Out:
# <tf.Tensor: shape=(2, 5), dtype=int32, numpy=
# array([[17, 35, 51, 42, 39],
#        [63,  8, 63, 84, 65]])>

# %%
tensor_a[2:4,1:3]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[35, 51],
#        [ 8, 63]])>

# %%
tensor_a[2:4,1:3] = [[1,2],[3,4]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 tensor_a[2:4,1:3] = [[1,2],[3,4]]
#
# TypeError: 'tensorflow.python.framework.ops.EagerTensor' object does not support item assignment

# %%
tensor_a = tf.Variable(tensor_a)
tensor_a
# Out:
# <tf.Variable 'Variable:0' shape=(5, 5) dtype=int32, numpy=
# array([[33, 92, 77, 70, 23],
#        [62, 73, 30, 20, 97],
#        [17, 35, 51, 42, 39],
#        [63,  8, 63, 84, 65],
#        [66,  3, 28, 56, 55]])>

# %%
tensor_a[2:4,1:3] = [[1,2],[3,4]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 tensor_a[2:4,1:3] = [[1,2],[3,4]]
#
# TypeError: 'ResourceVariable' object does not support item assignment

# %%
tensor_a[2:4,1:3]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[35, 51],
#        [ 8, 63]])>

# %%
tensor_a[2:4,1:3].assign([[1,2],[3,4]])
# Out:
# <tf.Variable 'UnreadVariable' shape=(5, 5) dtype=int32, numpy=
# array([[33, 92, 77, 70, 23],
#        [62, 73, 30, 20, 97],
#        [17,  1,  2, 42, 39],
#        [63,  3,  4, 84, 65],
#        [66,  3, 28, 56, 55]])>

# %%
tensor_a[::4,::4]
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[33, 23],
#        [66, 55]])>

# %%
tensor_a[::4,::4].assign(1000)
# Out:
# <tf.Variable 'UnreadVariable' shape=(5, 5) dtype=int32, numpy=
# array([[1000,   92,   77,   70, 1000],
#        [  62,   73,   30,   20,   97],
#        [  17,    1,    2,   42,   39],
#        [  63,    3,    4,   84,   65],
#        [1000,    3,   28,   56, 1000]])>

# %%
tf.transpose(tensor_a)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[1000,   62,   17,   63, 1000],
#        [  92,   73,    1,    3,    3],
#        [  77,   30,    2,    4,   28],
#        [  70,   20,   42,   84,   56],
#        [1000,   97,   39,   65, 1000]])>

# %%
tensor_a
# Out:
# <tf.Variable 'Variable:0' shape=(5, 5) dtype=int32, numpy=
# array([[1000,   92,   77,   70, 1000],
#        [  62,   73,   30,   20,   97],
#        [  17,    1,    2,   42,   39],
#        [  63,    3,    4,   84,   65],
#        [1000,    3,   28,   56, 1000]])>

# %%
tf.roll(tensor_a,shift=2,axis=1)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[  70, 1000, 1000,   92,   77],
#        [  20,   97,   62,   73,   30],
#        [  42,   39,   17,    1,    2],
#        [  84,   65,   63,    3,    4],
#        [  56, 1000, 1000,    3,   28]])>

# %%
tf.roll(tensor_a,shift=2,axis=0)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=int32, numpy=
# array([[  63,    3,    4,   84,   65],
#        [1000,    3,   28,   56, 1000],
#        [1000,   92,   77,   70, 1000],
#        [  62,   73,   30,   20,   97],
#        [  17,    1,    2,   42,   39]])>

# %%
import matplotlib.pyplot as plt

# %%
a = plt.imread(r"C:\Users\Lenovo\Desktop\kohli_image.jpg")

# %%
arr = a.copy()

# %%
print(arr)
# Out:
# [[[118 111  69]
#   [116 109  65]
#   [115 107  60]
#   ...
#   [218 203 184]
#   [219 204 185]
#   [217 204 185]]
#
#  [[117 113  66]
#   [114 111  60]
#   [112 106  54]
#   ...
#   [217 202 181]
#   [218 203 182]
#   [217 204 185]]
#
#  [[117 116  60]
#   [116 115  58]
#   [117 115  56]
#   ...
#   [217 202 181]
#   [218 203 182]
#   [216 204 182]]
#
#  ...
#
#  [[204 204 196]
#   [202 203 195]
#   [201 202 194]
#   ...
#   [254 253 251]
#   [253 252 250]
#   [251 250 246]]
#
#  [[209 205 202]
#   [205 204 199]
#   [203 204 198]
#   ...
#   [254 253 251]
#   [254 253 251]
#   [253 252 248]]
#
#  [[209 205 202]
#   [209 205 202]
#   [206 205 200]
#   ...
#   [254 253 251]
#   [255 254 250]
#   [255 254 250]]]

# %%
print(plt.imshow(arr))
# Out:
# AxesImage(shape=(654, 524, 3))

# %%
plt.imshow(np.rot90(arr,k=3))

# %%
tens = tf.Variable(arr)

# %%
print(tens)
# Out:
# <tf.Variable 'Variable:0' shape=(654, 524, 3) dtype=uint8, numpy=
# array([[[118, 111,  69],
#         [116, 109,  65],
#         [115, 107,  60],
#         ...,
#         [218, 203, 184],
#         [219, 204, 185],
#         [217, 204, 185]],
#
#        [[117, 113,  66],
#         [114, 111,  60],
#         [112, 106,  54],
#         ...,
#         [217, 202, 181],
#         [218, 203, 182],
#         [217, 204, 185]],
#
#        [[117, 116,  60],
#         [116, 115,  58],
#         [117, 115,  56],
#         ...,
#         [217, 202, 181],
#         [218, 203, 182],
#         [216, 204, 182]],
#
#        ...,
#
#        [[204, 204, 196],
#         [202, 203, 195],
#         [201, 202, 194],
#         ...,
#         [254, 253, 251],
#         [253, 252, 250],
#         [251, 250, 246]],
#
#        [[209, 205, 202],
#         [205, 204, 199],
#         [203, 204, 198],
#         ...,
#         [254, 253, 251],
#         [254, 253, 251],
#         [253, 252, 248]],
#
# ...

# %%
plt.imshow(tens)

# %%
plt.imshow(tens[480:540,150:390])

# %%
# Broadcasting

# %%
a = tf.Variable([1,24,5])
b = tf.Variable([10,14,15])

print(a)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([ 1, 24,  5])>

# %%
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 14, 15])>

# %%
print(a + b)
# Out:
# tf.Tensor([11 38 20], shape=(3,), dtype=int32)

# %%
a = tf.Variable(np.random.randint(1,50,(3,3)))
a
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[14,  3, 44],
#        [44,  7, 43],
#        [40, 39, 32]])>

# %%
b
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 14, 15])>

# %%
print(a + b)
# Out:
# tf.Tensor(
# [[24 17 59]
#  [54 21 58]
#  [50 53 47]], shape=(3, 3), dtype=int32)

# %%
a = tf.Variable(np.random.randint(1,50,(3,5)))
a
# Out:
# <tf.Variable 'Variable:0' shape=(3, 5) dtype=int32, numpy=
# array([[11, 16, 19, 34, 27],
#        [ 6, 30, 15, 38, 38],
#        [ 7, 37, 36, 24,  5]])>

# %%
b
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([10, 14, 15])>

# %%
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 print(a + b)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\variables.py:1013, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1011 def _run_op(a, *args, **kwargs):
#    1012   # pylint: disable=protected-access
# -> 1013   return tensor_oper(a.value(), *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:5883, in raise_from_not_ok_status(e, name)
# ...

# %%
a = tf.Variable(np.random.randint(1,50,(4,5)))
b = tf.Variable(np.random.randint(1,50,(5,4)))


print(a)
# Out:
# <tf.Variable 'Variable:0' shape=(4, 5) dtype=int32, numpy=
# array([[ 4, 43,  4, 17,  5],
#        [16, 10, 12, 37, 47],
#        [37, 11, 26,  1, 43],
#        [35, 16,  1,  3, 45]])>

# %%
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(5, 4) dtype=int32, numpy=
# array([[35, 16,  3, 17],
#        [25, 46, 38,  1],
#        [ 1,  9, 19, 19],
#        [22, 36, 33, 19],
#        [29, 10, 40, 21]])>

# %%
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 print(a + b)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\variables.py:1013, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1011 def _run_op(a, *args, **kwargs):
#    1012   # pylint: disable=protected-access
# -> 1013   return tensor_oper(a.value(), *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:5883, in raise_from_not_ok_status(e, name)
# ...

# %%
print(a * b)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 print(a * b)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\variables.py:1013, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1011 def _run_op(a, *args, **kwargs):
#    1012   # pylint: disable=protected-access
# -> 1013   return tensor_oper(a.value(), *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:5883, in raise_from_not_ok_status(e, name)
# ...

# %%
a = tf.Variable(np.random.randint(1,50,(3,3,5)))
b = tf.Variable(np.random.randint(1,50,(3,5)))


print(a)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3, 5) dtype=int32, numpy=
# array([[[ 7, 28,  8,  8, 34],
#         [ 2, 40, 43, 44, 20],
#         [36, 39, 11,  8,  9]],
#
#        [[15, 13, 43, 17, 21],
#         [15, 30, 24,  5, 38],
#         [15, 34, 43, 17, 32]],
#
#        [[44, 18, 35, 12, 17],
#         [30, 36, 12, 43, 14],
#         [40, 30, 32, 10, 31]]])>

# %%
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 5) dtype=int32, numpy=
# array([[17, 16, 47, 44, 17],
#        [24, 47, 32, 48,  6],
#        [24, 27,  2, 28, 25]])>

# %%
print(a + b)
# Out:
# tf.Tensor(
# [[[24 44 55 52 51]
#   [26 87 75 92 26]
#   [60 66 13 36 34]]
#
#  [[32 29 90 61 38]
#   [39 77 56 53 44]
#   [39 61 45 45 57]]
#
#  [[61 34 82 56 34]
#   [54 83 44 91 20]
#   [64 57 34 38 56]]], shape=(3, 3, 5), dtype=int32)

# %% [markdown]
# https://numpy.org/doc/stable/user/basics.broadcasting.html
