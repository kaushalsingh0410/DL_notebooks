# %%
print('Ritu')
# Out:
# Ritu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Flatten, Conv2D,MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix

import joblib

# %%
(X_train,y_train),(X_test,y_test) = cifar10.load_data()
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
classes = '''0	airplane
1	automobile
2	bird
3	cat
4	deer
5	dog
6	frog
7	horse
8	ship
9	truck'''

classes = classes.split()[1::2]
classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
X_train_s = X_train.astype('float32')/255
X_test_s = X_test.astype('float32')/255
y_train_f = y_train.flatten()
y_test_f = y_test.flatten()

# %%
from random import randint
def show_image(X = X_train,y = y_train_f,ind = None):
  ind = randint(0,len(X)) if ind is None else ind
  plt.figure(figsize = (1,1))
  plt.imshow(X[ind])
  plt.title(classes[y[ind]])
  plt.show()

show_image()

# %%
show_image(X = X_train_s,y= y_train_f,ind= 0)

# %%
early_stop = EarlyStopping(monitor = 'val_loss',
                           patience = 3,
                           min_delta = 0.001,
                           verbose = 1,)

# %%
# model = Sequential([
#     Flatten(input_shape = X_train_s[0].shape),
#     Dense(1000,activation = 'relu'),
#     Dense(500,activation = 'relu'),
#     Dense(100,activation = 'relu'),
#     Dense(50,activation = 'relu'),
#     Dropout(0.2),
#     Dense(10,activation = 'softmax')
# ])

# model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])
# model.fit(X_train_s,y_train,epochs = 5,validation_data = (X_test_s,y_test),callbacks= early_stop)

# %%
# model1 = Sequential([
#     Conv2D(32,(3,3),activation = 'relu',input_shape = X_train_s[0].shape),
#     MaxPooling2D((2,2)),
#     Conv2D(64,(3,3),activation = 'relu'),
#     MaxPooling2D((2,2)),
#     Conv2D(32,(3,3),activation = 'relu'),
#     MaxPooling2D((2,2)),
#     Flatten(),
#     Dense(100,activation = 'relu'),
#     Dense(50,activation = 'relu'),
#     Dense(25,activation = 'relu'),
#     Dropout(0.3),
#     Dense(100,activation = 'softmax'),
# ])

# model1.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'] )
# model1.fit(X_train_s,y_train,epochs = 10,validation_data = (X_test_s,y_test),callbacks = early_stop)

# %%
# model2 = Sequential([
#     Conv2D(32,(3,3),activation = 'relu',input_shape = X_train_s[0].shape,padding = 'same'),
#     MaxPooling2D((2,2)),
#     Conv2D(64,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),
#     Conv2D(64,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),
#     Conv2D(32,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),
#     Flatten(),
#     Dense(100,activation = 'relu'),
#     Dense(50,activation = 'relu'),
#     Dense(25,activation = 'relu'),
#     Dropout(0.2),
#     Dense(10,activation = 'softmax'),
# ])

# model2.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])
# model2.fit(X_train_s,y_train,epochs = 30,validation_data = (X_test_s,y_test),callbacks = early_stop)

# %%
# import joblib

# %%
# joblib.dump(model2,'cifar_final_model.pkl')

# %%
# y_pred = model2.predict(X_test_s)

# %%
# sns.heatmap(confusion_matrix(y_test,y_pred.argmax(axis = 1)),annot = True,fmt= 'd')

# %%
# classes[5],classes[3]

# %%
# classes[2],classes[0]

# %%
# classes[2],classes[3]

# %%
# classes[2],classes[4]

# %%
# classes[2],classes[5]

# %%
# y_pred = model2.predict(X_test_s[:6])

# %%
# y_pred.argmax(axis = 1)

# %%
# y_test_f = y_test.flatten()

# %%
# y_test_f[:6]

# %%
# for i in range(100):
#   ind = randint(1,len(X_test_s))
#   print(classes[model2.predict(X_test_s[[ind]]).argmax()])
#   show_image(X_test_s,y_test,ind)

# %% [markdown]
# # With out Eraly Stopping

# %%
# model3 = Sequential([
#     Conv2D(32,(3,3),activation = 'relu',input_shape = X_train_s[0].shape,padding = 'same'),
#     MaxPooling2D((2,2)),

#     Conv2D(64,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),

#     Conv2D(64,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),

#     Conv2D(32,(3,3),activation = 'relu',padding = 'same'),
#     MaxPooling2D((2,2)),

#     Flatten(),

#     Dense(100,activation = 'relu'),
#     Dense(50,activation = 'relu'),
#     Dense(25,activation = 'relu'),
#     Dropout(0.2),
#     Dense(10,activation = 'softmax'),
# ])

# model3.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])
# model3.fit(X_train_s,y_train_f,epochs = 30)

# %%
# joblib.dump(model3,'cifar_final_model.pkl')

# %%
model3 = joblib.load('cifar_final_model.pkl')

# %%
y_pred = model3.predict(X_test_s).argmax(axis = 1)
sns.heatmap(confusion_matrix(y_test_f,y_pred),annot = True,fmt = 'd')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step
# <Axes: >

# %%
for i in range(30):
  ind =randint(1,len(X_test_s))
  print(classes[model3.predict(X_test_s[[ind]]).argmax()])
  show_image(X = X_test_s,y = y_test_f,ind = ind)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# ship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# dog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# truck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# horse
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# horse
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# dog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# automobile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# deer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# frog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# deer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# deer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# truck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# truck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# truck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# bird
# ...

# %%
classes[model3.predict(X_test_s[[ind]]).argmax()]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 'horse'

# %%
model3.evaluate(X_test_s,y_test_f)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.7194 - loss: 1.2532
# [1.2806880474090576, 0.71670001745224]

# %%
model3.history.history
# Out:
# {}
